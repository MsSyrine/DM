# %% [markdown]
# <h1>
# Analysis of the Driving Factors in a Film
# </h1>

# %%
#Import packages
import pandas as pd
import numpy as np

import json
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Import the datasets into dataframes
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
#A Quick Look at the dataframe: Credits
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
#A Quick Look at the dataframe: movies
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#Filters to limit the data and remove outliers
movies = movies[movies.original_language == 'en']#keep only original english movies
movies = movies[movies.vote_count != 0] #keep movies with non null votes
movies = movies[movies.genres != '[]']  #keep movies with non null genres

# %%
#Clean the Dataset
#Create new dataframes from Dictionary like columns
def mapper(df, col, new_col):
    temp = []
    for n, row in df.iterrows():
        [temp.append(tuple(i.values())+(row[new_col],)) for i in json.loads(row[col])]
        
    new_df = pd.DataFrame(temp)
    new_df.columns = list(json.loads(row[col])[0].keys()) + ['movie_id']

    return new_df

# %%
#Extracting the Data from json like columns

#extract from the credits dataset json like columns
credit_cast = mapper(credits, 'cast', 'movie_id')#cast credits
credit_crew = mapper(credits, 'crew', 'movie_id')#crew credits

#extract from the movies dataset json like columns
movie_genres = mapper(movies, 'genres', 'id') #genre
movie_keywords = mapper(movies, 'keywords', 'id') #keywords describing the movie
movie_production_companies = mapper(movies, 'production_companies', 'id') 
movie_spoken_languages = mapper(movies, 'spoken_languages', 'id')
movie_production_countries = mapper(movies, 'production_countries', 'id')

# %%
movie_genres.columns # visualizing the movies genre columns
# Out:
# Index(['id', 'name', 'movie_id'], dtype='object')

# %%
#Renaming the columns for better understanding of the data fields
#renaming cast columns
credit_cast.columns = ['cast_id', 'character', 'credit_id', 'gender', 'actor_id', 'actor_name', 'order','movie_id']
#renaming crew columns
credit_crew.columns = ['credit_id', 'department', 'gender', 'job_id', 'job', 'crew_member', 'movie_id']
#renaming movie genres columns
movie_genres.columns = ['genre_id','genre','movie_id']
#renaming movie production's companies columns
movie_production_companies.columns = ['studio', 'studio_id', 'movie_id']

movie_spoken_languages.columns = ['iso_639_1', 'language', 'movie_id']#ISO 639-1 is the standard of language codes

movie_production_countries.columns = ['iso_3166_1', 'country', 'movie_id']#codes ISO 3166 des pays

# %%
#Understanding the Genres of the movies
arranged_data = movie_genres.groupby('genre')['movie_id'].nunique()#show number of unique movies based on the genre column
ax = arranged_data.plot(figsize=(20,10), kind='bar', fontsize=13)
ax.set_xlabel('Genres', fontsize=15)
ax.set_ylabel('Movies made in numbers', fontsize=15)
plt.show()

# %% [raw]
# movie_genres.head()

# %% [raw]
# movies.head()

# %% [markdown]
# # FIRST APPROACH
#
# first ,we are considering in our metrics the movies popularity,revenue,runtime,vote count,vote average and the budget.
# we proceed by defining the columns of the metrics so it adjust to the data contained
# Secondly,after properly defining the metrics data,we perform a merge/inner join to combine the movie_genres with metrics based on movie_id (a commonly shared unique field)
# Then we calculate the weights corresponding to each field within the metrics so that we can determine what movies can be considered as successful

# %%
#Creating a Weights dataframe to attach genre-wise weights to the movies,
#These weights are decided by various aspects
metrics = movies[['id','popularity','revenue','runtime','vote_count','vote_average','budget']]
#defining metrics by selecting the most important features wihin the movies dataset

# %% [raw]
# metrics.head()

# %%
metrics.columns = ['movie_id','popularity','revenue','runtime','vote_count','vote_average','budget']#renaming metrics columns for better representation of the data contained

# %% [raw]
# metrics.head() #visualizing the first five elements of the metrics data

# %% [raw]
# movie_genres.head()

# %%
genre_df = pd.merge(movie_genres, metrics, on='movie_id',how='inner') #inner join on movie_id


weights = genre_df.groupby('genre').agg({'movie_id':'count', 'revenue':'mean','runtime':'mean', 
                           'vote_count':'count','vote_average':'mean','budget':'mean'})

import seaborn as sns#for visualizing the weights of movies when it comes to rating the genre

weights = weights.reset_index().sort_values('vote_average',ascending=True)

plt.figure(figsize=(20,10))

sns.violinplot(x=genre_df['genre'], y=genre_df['vote_average'], linewidth=0.5,fontsize=15)

plt.ylabel('Rating',fontsize=13)
plt.xlabel('Genres',fontsize=13)
plt.title(' Average rating by genre ',fontsize=15)
plt.show()

# %% [raw]
# here we find ourselves versus a major problem faced in many machine learning algorithms ,the differences in the ranges of values within the dataset ,especially when it comes to the budget values are very distorting and can affect the predictions,and calculations
# We need to perform a  normalization on the dataset to change the values of numeric columns in the dataset to a common scale.

# %%
 #first we try an approach of metrics without taking the budget values into consideration
metrics = movies[['id','popularity','revenue','runtime','vote_count','vote_average']]
metrics.columns = ['movie_id','popularity','revenue','runtime','vote_count','vote_average']

weights = pd.merge(movie_genres, metrics, on='movie_id',how='inner')
weights = weights.groupby('genre').agg({'movie_id':'count', 'revenue':'mean','runtime':'mean', 
                           'vote_count':'count','vote_average':'mean'})
weights.head()


plt.figure(figsize=(20,10))

sns.violinplot(x=genre_df['genre'], y=genre_df['vote_average'], linewidth=0.5,fontsize=15)

plt.ylabel('Rating',fontsize=13)
plt.xlabel('Genres',fontsize=13)
plt.title(' Average rating by genre ',fontsize=15)
plt.show()

# %% [raw]
# in the next parts,we are going to use MinMaxScaler which Transforms features by scaling each feature to a given range.
# This estimator scales and translates each feature individually such that it is in the given range on the training set, e.g. between zero and one.
# Thus we garantee that the values within our metrics will shift from values measured on different scales to a notionally common scale and therefore becomes normalized

# %%
from sklearn.preprocessing import MinMaxScaler 
ss = MinMaxScaler()

metrics = movies[['id','popularity','revenue','runtime','vote_count','vote_average']]
metrics.columns = ['movie_id','popularity','revenue','runtime','vote_count','vote_average']

weights = pd.merge(movie_genres, metrics, on='movie_id',how='inner')
weights = weights.groupby('genre').agg({'movie_id':'count', 'revenue':'mean','runtime':'mean', 
                           'vote_count':'count','vote_average':'mean'})


weights_scores = np.sum(ss.fit_transform(weights),axis=1)
# Out:
# C:\Users\syrin\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
weights.index
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'Foreign', 'History', 'Horror', 'Music',
#        'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War',
#        'Western'],
#       dtype='object', name='genre')

# %%
weights_scores
# Out:
# array([2.41279643, 2.52939388, 1.87708062, 2.43572985, 1.9525513 ,
#        1.2330679 , 3.46490843, 1.74275873, 1.9944113 , 0.98973767,
#        2.40547642, 0.86269429, 1.54107024, 1.61103362, 2.01233923,
#        1.84310453, 0.        , 2.27289893, 2.33389408, 1.55827941])

# %%
scores_df = pd.DataFrame({'Genres':list(weights.index),'weights':weights_scores})#combine in a dataFrame the weights index and scores

weights = weights_scores#update the weights with the weight scores

scores_df.plot(kind='bar')#visualise sthe scoreds dataframe,x:wieghts indexes , y:scores

# %%
scores_df #visualise values
# Out:
#              Genres   weights
# 0            Action  2.412796
# 1         Adventure  2.529394
# 2         Animation  1.877081
# 3            Comedy  2.435730
# 4             Crime  1.952551
# 5       Documentary  1.233068
# 6             Drama  3.464908
# 7            Family  1.742759
# 8           Fantasy  1.994411
# 9           Foreign  0.989738
# 10          History  2.405476
# 11           Horror  0.862694
# 12            Music  1.541070
# 13          Mystery  1.611034
# 14          Romance  2.012339
# 15  Science Fiction  1.843105
# 16         TV Movie  0.000000
# 17         Thriller  2.272899
# 18              War  2.333894
# 19          Western  1.558279

# %%
def score_calculator(df1, df2, col):#this function is for calculating the score of two data entities according to a given column feature
    joined_df = pd.merge(df1, df2, on ='movie_id')
    
    #pivot tables and make the col as an index and fill the NaN values with 0
    temp = joined_df.pivot_table(index = col, columns = 'genre', values = 'genre_id', aggfunc = 'count').fillna(0)
    
    df_index = temp.index
    #calculate the score for each column property of the newly joined data element
    score_df = pd.DataFrame(np.matmul(temp.values, weights))
    score_df.index = df_index
    score_df.columns = ['score']
    score_df = score_df.sort_values(by='score',ascending=False).reset_index()
    #perform an inner join on movie_id and calculate the sum score
    score = pd.merge(df1, score_df, on = col, how = 'inner').groupby('movie_id')['score'].sum().reset_index()
    score.columns = ['movie_id',col+'_score']
    
    return score

# %%
credit_cast.head()
# Out:
#    cast_id            character                 credit_id  gender  actor_id  \
# 0      242           Jake Sully  5602a8a7c3a3685532001c9a       2     65731
# 1        3              Neytiri  52fe48009251416c750ac9cb       1      8691
# 2       25  Dr. Grace Augustine  52fe48009251416c750aca39       1     10205
# 3        4        Col. Quaritch  52fe48009251416c750ac9cf       2     32747
# 4        5         Trudy Chacon  52fe48009251416c750ac9d3       1     17647
#
#            actor_name  order  movie_id
# 0     Sam Worthington      0     19995
# 1         Zoe Saldana      1     19995
# 2    Sigourney Weaver      2     19995
# 3        Stephen Lang      3     19995
# 4  Michelle Rodriguez      4     19995

# %%
movie_genres.head()
# Out:
#    genre_id            genre  movie_id
# 0        28           Action     19995
# 1        12        Adventure     19995
# 2        14          Fantasy     19995
# 3       878  Science Fiction     19995
# 4        12        Adventure       285

# %%
crew_score = score_calculator(credit_crew, movie_genres, 'crew_member')
crew_score.head()
# Out:
#    movie_id  crew_member_score
# 0         5        4382.761537
# 1        11        2065.131772
# 2        12        4150.947014
# 3        13        5331.519244
# 4        14        4392.269801

# %%
cast_score = score_calculator(credit_cast, movie_genres, 'actor_name')
cast_score.head()
# Out:
#    movie_id  actor_name_score
# 0         5       1559.632692
# 1        11       1872.556765
# 2        12       1650.824548
# 3        13       1560.893005
# 4        14       1332.531829

# %%
production_score = score_calculator(movie_production_companies, movie_genres, 'studio')
production_score.head()
# Out:
#    movie_id  studio_score
# 0         5    612.523142
# 1        11   1583.527235
# 2        12    114.695539
# 3        13   1779.547531
# 4        14    528.945508

# %%
#Actor
#here we perform a join between the credit cast and the movie genre in order to determine in later steps the actors having the best scores
joined_df = pd.merge(credit_cast, movie_genres, on ='movie_id')
temp = joined_df.pivot_table(index = 'actor_name', columns = 'genre', values = 'genre_id', aggfunc = 'count').fillna(0)
df_index = temp.index

score_df = pd.DataFrame(np.matmul(temp.values, weights))
score_df.index = df_index
score_df.columns = ['Score']
score_df.sort_values(ascending=False, by='Score').head(10).plot(figsize=(20,10), kind='bar', fontsize=13,color=(0.7,0.7,0.8))

#graph plotting
plt.xlabel('Actors',fontsize=15)
plt.ylabel('Scores',fontsize=15)
plt.title('Top 10 Actor Scores',fontsize=15)
plt.show()

# %%
#Studio
#here we perform a join between the movies genres and the movie production companies in order to determine in later steps the studios having the best scores
joined_df = pd.merge(movie_production_companies, movie_genres, on ='movie_id')
temp = joined_df.pivot_table(index = 'studio', columns = 'genre', values = 'genre_id', aggfunc = 'count').fillna(0)
df_index = temp.index
score_df = pd.DataFrame(np.matmul(temp.values, weights))
score_df.index = df_index
score_df.columns = ['Score']
score_df.sort_values(ascending=False, by='Score').head(10).plot(figsize=(20,10), kind='bar', fontsize=13,color=(0.7,0.7,0.8))
plt.xlabel('Studios',fontsize=15)
plt.ylabel('Scores',fontsize=15)
plt.title('Top 10 Studio Scores',fontsize=15)
plt.show()

# %%
#Crew
#here we perform a join between the credit crew and the movie genre in order to determine in later steps the crews having the best scores

joined_df = pd.merge(credit_crew, movie_genres, on ='movie_id')
temp = joined_df.pivot_table(index = 'crew_member', columns = 'genre', values = 'genre_id', aggfunc = 'count').fillna(0)
df_index = temp.index
score_df = pd.DataFrame(np.matmul(temp.values, weights))
score_df.index = df_index
score_df.columns = ['Score']
score_df.sort_values(ascending=False, by='Score').head(10).plot(figsize=(20,10), kind='bar', fontsize=13,color=(0.7,0.7,0.8))
plt.xlabel('Crew',fontsize=15)
plt.ylabel('Scores',fontsize=15)
plt.title('Top 10 Crew Scores',fontsize=15)
plt.show()

# %% [raw]
# the release date of a movie plays an important part in determining the movie's score,for a example a movie released during the winter holidays can score better than a movie released in the begining of the autumn(back to school season)
# in order to be able to work with the date feature,we need to limit the interval of the feature value and transform it into a value based on the month season

# %%
movies['release_month'] = movies.release_date.str.split('-').apply(lambda x:int(x[1]))
def season(row):
    if row >= 1 and row < 4:
        return 'winter'
    elif row >= 4 and row < 7:
        return 'spring'
    elif row >= 7 and row < 10:
        return 'summer'
    elif row >= 10 and row < 12:
        return 'autumn'
    else:
        return 'winter'

movies['season'] = movies.release_month.apply(season)
movies.columns
data = movies.drop(['genres', 'homepage', 'keywords', 'original_title', 'overview', 'production_companies', 
                    'release_date', 'production_countries', 'spoken_languages', 'status', 'tagline',
                    'release_month'],axis=1)
data.columns = ['budget', 'movie_id', 'original_language', 'popularity', 'revenue', 'runtime', 'title', 'vote_average',
                'vote_count', 'season']#add the season feature

#perform join operation based on the movie_id
data = pd.merge(data, cast_score, on='movie_id', how='inner')
data = pd.merge(data, production_score, on='movie_id', how='inner')
data = pd.merge(data, crew_score, on='movie_id', how='inner')

data.head()
# Out:
#       budget  movie_id original_language  popularity     revenue  runtime  \
# 0  237000000     19995                en  150.437577  2787965087    162.0
# 1  300000000       285                en  139.082615   961000000    169.0
# 2  245000000    206647                en  107.376788   880674609    148.0
# 3  250000000     49026                en  112.312950  1084939099    165.0
# 4  260000000     49529                en   43.926995   284139100    132.0
#
#                                       title  vote_average  vote_count  season  \
# 0                                    Avatar           7.2       11800  winter
# 1  Pirates of the Caribbean: At World's End           6.9        4500  spring
# 2                                   Spectre           6.3        4466  autumn
# 3                     The Dark Knight Rises           7.6        9106  summer
# 4                               John Carter           6.1        2124  winter
#
# ...

# %%
def plot_hist(df, col, title, x, y):
    temp = data[['title', col]].sort_values(by=col, ascending=True).head(10)#take only ten elements
    
    ax = temp.set_index('title').plot(kind='bar', figsize=(20,10), fontsize=13)
    ax.set_xlabel(x, fontsize=13)
    ax.set_ylabel(y, fontsize=13)
    ax.set_title(title, fontsize=15)
    
    plt.show()
#visualize the latest updated data with the actor name and actors movies scores
plot_hist(data, 'actor_name_score', 'Movies with Highest Actor Scores', 'Movies', 'Actor Score')

# %%
plot_hist(data, 'studio_score', 'Movies with Highest Production Scores', 'Movies', 'Studio Score')

# %%
plot_hist(data, 'crew_member_score', 'Movies with Highest Behind the Scenes Scores', 'Movies', 'Behind the Scenes Score')

# %%
#Creating the Target Variables
#we define a threshold value for each of the vote_average,popularity and budget features where we consider 
#any movie having a lower value than this threshold as a failed movie
def create_labels(row):
    if (row['vote_average']>= 5.5)&(row['popularity']>50)&((row['revenue']-row['budget'])>0):
        return 1
    else:
        return 0

data['target'] = data[['vote_average','popularity','revenue', 'budget']].apply(create_labels,axis=1)
data.head()
# Out:
#       budget  movie_id original_language  popularity     revenue  runtime  \
# 0  237000000     19995                en  150.437577  2787965087    162.0
# 1  300000000       285                en  139.082615   961000000    169.0
# 2  245000000    206647                en  107.376788   880674609    148.0
# 3  250000000     49026                en  112.312950  1084939099    165.0
# 4  260000000     49529                en   43.926995   284139100    132.0
#
#                                       title  vote_average  vote_count  season  \
# 0                                    Avatar           7.2       11800  winter
# 1  Pirates of the Caribbean: At World's End           6.9        4500  spring
# 2                                   Spectre           6.3        4466  autumn
# 3                     The Dark Knight Rises           7.6        9106  summer
# 4                               John Carter           6.1        2124  winter
#
# ...

# %% [raw]
# pd.get_dummies(data.drop(['target','movie_id','title','original_language',
#                               'budget', 'revenue', 'vote_average', 'vote_count', 'popularity'],axis=1)).head()

# %%
#Getting the feature and target vector
#perform a get dummies operation in order to transform the non numeric value of each season into binary values (almost boolean 1/0)
X = pd.get_dummies(data.drop(['target','movie_id','title','original_language', 
                              'budget', 'revenue', 'vote_average', 'vote_count', 'popularity'],axis=1)).values
y = data['target'].values
cols = list(pd.get_dummies(data.drop(['target','movie_id','title','original_language', 
                              'budget', 'revenue', 'vote_average', 'vote_count', 'popularity'],axis=1)).columns)

# %%
X
# Out:
# array([[1.62000000e+02, 1.94515131e+03, 2.08546190e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [1.69000000e+02, 2.25940778e+03, 9.78368741e+02, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.48000000e+02, 1.62735135e+03, 1.29249128e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [7.70000000e+01, 1.60910964e+02, 2.39930769e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.20000000e+02, 1.89664148e+02, 2.56757011e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.00000000e+01, 8.49511117e+02, 2.46613579e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
#Divide the data into training and testing
from sklearn.model_selection import train_test_split #for partitioning data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)
#here we pass 0.3 as the value, the dataset will be split 30% as the test dataset.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

# %% [raw]
# clfs = {'dt': DecisionTreeClassifier(random_state=0),#hedhi eli besh neksmouha twali bel ka3ba bel ka3ba
#         'rf': RandomForestClassifier(random_state=0)}

# %%
# The list of [best_score_, best_params_, best_estimator_]
best_score_param_estimators = []

# %%
#DecisionTreeClassifier
gs = GridSearchCV(estimator=Pipeline([('StandardScaler', StandardScaler()), ('clf', DecisionTreeClassifier(random_state=0))]),
                param_grid=[{'clf__min_samples_split': [2, 10, 30],
               'clf__min_samples_leaf': [1, 10, 30]}], scoring='accuracy',
                  n_jobs=-1,cv=StratifiedKFold(n_splits=10, shuffle=True, random_state=10))
# Fit the pipeline
gs.fit(X_train, y_train)
    
# Update best_score_param_estimators
best_score_param_estimators.append([gs.best_score_, gs.best_params_, gs.best_estimator_])

# %%
#RandomForestClassifier
gs = GridSearchCV(estimator=Pipeline([('StandardScaler', StandardScaler()), ('clf', RandomForestClassifier(random_state=0))]), 
                param_grid=[{'clf__n_estimators': [2, 10, 30],
               'clf__min_samples_split': [2, 10, 30],
               'clf__min_samples_leaf': [1, 10, 30]}], scoring='accuracy', n_jobs=-1, 
                      cv=StratifiedKFold(n_splits=10, shuffle=True, random_state=10))
# Fit the pipeline
gs.fit(X_train, y_train)
    
# Update best_score_param_estimators
best_score_param_estimators.append([gs.best_score_, gs.best_params_, gs.best_estimator_])

# %%
# Sort best_score_param_estimators in descending order of the best_score_
best_score_param_estimators = sorted(best_score_param_estimators, key=lambda x : x[0], reverse=True)

# For each [best_score_, best_params_, best_estimator_]
for best_score_param_estimator in best_score_param_estimators:
    # Print out [best_score_, best_params_, best_estimator_], where best_estimator_ is a pipeline
    # Since we only print out the type of classifier of the pipeline
    print([best_score_param_estimator[0], best_score_param_estimator[1], type(best_score_param_estimator[2].named_steps['clf'])], end='\n\n')
# Out:
# [0.9054982817869416, {'clf__min_samples_leaf': 1, 'clf__min_samples_split': 30, 'clf__n_estimators': 30}, <class 'sklearn.ensemble.forest.RandomForestClassifier'>]
#
# [0.8938144329896908, {'clf__min_samples_leaf': 30, 'clf__min_samples_split': 2}, <class 'sklearn.tree.tree.DecisionTreeClassifier'>]

# %%
from sklearn.metrics import confusion_matrix

# %%
#RandomForestClassifier
y_pred = best_score_param_estimators[0][2].predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[1113,   10],
#        [ 105,   20]], dtype=int64)

# %%
#DecisionTreeClassifier

y_pred = best_score_param_estimators[1][2].predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[1098,   25],
#        [ 101,   24]], dtype=int64)

# %%
#  Recreate the Random Forest Classifier with the same parameters
rf = RandomForestClassifier(min_samples_leaf= 10, min_samples_split= 30, n_estimators= 30, random_state=0)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.19220357, 0.2108089 , 0.12029351, 0.43789696, 0.00904738,
#        0.01262048, 0.00788346, 0.00924573])

# %%
eval_df = pd.DataFrame({'Feature':cols, 'Importances':rf.feature_importances_})
ax = eval_df.plot(kind='bar', figsize=(20,10), fontsize=13)
plt.title('Feature Importances', fontsize=15)
ax.set_xlabel('Features', fontsize=13)
ax.set_ylabel('Importance Scores by sklearn', fontsize=13)
plt.xticks(list(range(0,8)),cols)
plt.show()
